# %% [markdown]
# <a href="https://colab.research.google.com/github/manueltrs/Carta-Interactiva-Romantica/blob/main/seccion6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Los puntos principales tratados en el video son:**
#
# **PMBOK 8.ª edición:** plantea una gestión más práctica y flexible, enfocada en principios y en la creación de valor, reduciendo la burocracia.
# Portafolios, programas y operaciones: los proyectos no deben verse de manera aislada, sino como parte de una estrategia organizacional que permita utilizar los recursos donde generen mayor beneficio.
#
# **Entrega de valor:** el éxito no consiste simplemente en entregar software funcionando. Lo importante es que sea adoptado y produzca resultados como mayor productividad, rentabilidad o satisfacción del cliente.
#
# **Viabilidad:** antes de desarrollar un proyecto se debe identificar la necesidad del negocio, establecer objetivos medibles y definir criterios claros para determinar si tuvo éxito.
#
# **Business Case y Project Charter:** el caso de negocio demuestra que el proyecto es económicamente viable y está alineado con la estrategia; el acta constitutiva autoriza formalmente el proyecto y otorga autoridad al director del proyecto.
#
# **Herramientas de gestión:** también son importantes elementos como la matriz RACI, EDT/LDT, diagramas de Gantt, valor ganado y registro de riesgos, porque permiten organizar, controlar y evaluar el proyecto.
#
# **En conclusión:** un buen gerente de proyectos de software no debe pensar únicamente en código y entregables, sino en cómo la tecnología resuelve una necesidad real y genera un valor medible para la organización.
